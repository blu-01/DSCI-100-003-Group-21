# %%
# Out:
# Error in read_delim("reprocessed.hungarian.data", delim = " "): could not find function "read_delim"
# Traceback:

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.2     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.0
# ✔ ggplot2   3.4.2     ✔ tibble    3.2.1
# ✔ lubridate 1.9.2     ✔ tidyr     1.3.0
# ✔ purrr     1.0.1
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors

# %%
test <- read_delim("reprocessed.hungarian.data", delim = " ")
test
# Out:
# New names:
# • `0` -> `0...6`
# • `0` -> `0...7`
# • `0` -> `0...9`
# • `0` -> `0...10`
# • `-9` -> `-9...11`
# • `-9` -> `-9...12`
# • `-9` -> `-9...13`
# • `0` -> `0...14`
# Rows: 293 Columns: 14
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: " "
# dbl (14): 40, 1, 2, 140, 289, 0...6, 0...7, 172, 0...9, 0...10, -9...11, -9....
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#     40 1 2 140 289 0...6 0...7 172 0...9 0...10 -9...11 -9...12 -9...13 0...14
# 1   49 0 3 160 180  0    0     156 0     1.0     2      -9      -9      1
# 2   37 1 2 130 283  0    1      98 0     0.0    -9      -9      -9      0
# 3   48 0 4 138 214  0    0     108 1     1.5     2      -9      -9      3
# 4   54 1 3 150  -9  0    0     122 0     0.0    -9      -9      -9      0
# ...
